# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#stats
from scipy import stats

# %%
# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(10)

# %%
plt.hist(dataset1)
# Out:
# (array([ 1.,  0.,  1.,  1.,  1.,  2.,  0.,  1.,  1.,  2.]),
#  array([-2.02102994, -1.66291989, -1.30480984, -0.94669979, -0.58858974,
#         -0.23047969,  0.12763036,  0.4857404 ,  0.84385045,  1.2019605 ,
#          1.56007055]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
# Out:
# (array([  1.,   4.,   6.,  14.,  21.,  14.,  10.,   6.,   2.,   2.]),
#  array([-2.33849993, -1.84630868, -1.35411744, -0.8619262 , -0.36973496,
#          0.12245628,  0.61464753,  1.10683877,  1.59903001,  2.09122125,
#          2.58341249]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,color='black',alpha=0.8,bins = 20)
plt.hist(dataset2,normed=True,color='blue',alpha=0.8,bins = 20)
# Out:
# (array([ 0.05079326,  0.        ,  0.10158653,  0.10158653,  0.05079326,
#          0.25396632,  0.40634612,  0.30475959,  0.66031244,  0.40634612,
#          0.15237979,  0.55872591,  0.20317306,  0.30475959,  0.20317306,
#          0.10158653,  0.05079326,  0.05079326,  0.05079326,  0.05079326]),
#  array([-2.33849993, -2.0924043 , -1.84630868, -1.60021306, -1.35411744,
#         -1.10802182, -0.8619262 , -0.61583058, -0.36973496, -0.12363934,
#          0.12245628,  0.36855191,  0.61464753,  0.86074315,  1.10683877,
#          1.35293439,  1.59903001,  1.84512563,  2.09122125,  2.33731687,
#          2.58341249]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex',color='orange')
